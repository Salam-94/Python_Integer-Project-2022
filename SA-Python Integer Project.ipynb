# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#INTEGER

# %%
5
# Out:
# 5

# %%
type (6)
# Out:
# int

# %%
type (4.3)
# Out:
# float

# %%
c= 5

# %%
name= "My name is Shahbaz"

# %%
print (name)
# Out:
# My name is Shahbaz

# %%
c
# Out:
# 5

# %%
type (c)
# Out:
# int

# %%
#working with integers

# %%
6+4 #Addition
# Out:
# 10

# %%
9-3 #subtraction
# Out:
# 6

# %%
5*7 #multiplication
# Out:
# 35

# %%
25/5 #Divide
# Out:
# 5.0

# %%
13%7 #Mudolo(reminder)
# Out:
# 6

# %%
#presidence/priority of operators

# %%
8*27/9
# Out:
# 24.0

# %%
4*3*2
# Out:
# 24

# %%
9+7*6
# Out:
# 51

# %%
6*(3+2)
# Out:
# 30

# %%
15//4 # 3.75 in this case output always take before decimal as default
# Out:
# 3

# %%
#Thank you
